# %%
from IPython.core.interactiveshell import InteractiveShell # makes all cells allow multiple outputs
from IPython.core.display import HTML, display
from IPython.display import IFrame
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
plt.style.use('bmh') # prettier plots
plt.rcParams['figure.figsize'] = (8, 6)
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = 10
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyCT2G-lKKPOLe6s7rypBp95apdWAUtmulo") # Your Google API key

locations = gmaps.datasets.load_dataset("taxi_rides")

fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations))
fig

# %%
from IPython.display import Image
Image(filename='/Users/silv/Downloads/map1.png')

# %%
from bokeh.io import output_file, show
from bokeh.models import GeoJSONDataSource
from bokeh.plotting import figure
from bokeh.sampledata.sample_geojson import geojson

geo_source = GeoJSONDataSource(geojson=geojson)

p = figure()
p.circle(x='x', y='y', alpha=0.9, source=geo_source)
output_file("geojson.html")
show(p)
# Out:
# GlyphRenderer(id='8a379c79-0ba5-4036-92c6-c3575982aa64', ...)
# INFO:bokeh.core.state:Session output file 'geojson.html' already exists, will be overwritten.
# ERROR:/usr/local/lib/python2.7/site-packages/bokeh/core/validation/check.pyc:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: x, y [renderer: GlyphRenderer(id='3707ee86-113d-45ac-9734-adfb4ac6c11b', ...)]
# ERROR:/usr/local/lib/python2.7/site-packages/bokeh/core/validation/check.pyc:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: x, y [renderer: GlyphRenderer(id='8a379c79-0ba5-4036-92c6-c3575982aa64', ...)]

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()


from bokeh.io import output_notebook, show, push_notebook

output_notebook()

from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)

map_options = GMapOptions(lat=30.29, lng=-97.73, map_type="roadmap", zoom=11)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options
)
plot.title.text = "Austin"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyCT2G-lKKPOLe6s7rypBp95apdWAUtmulo"

source = ColumnDataSource(
    data=dict(
        lat=[30.29, 30.20, 30.29],
        lon=[-97.70, -97.74, -97.78],
    )
)

circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
#output_file("gmap_plot.html")
show(plot,notebook_handle=True)
#display(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id
type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"96755e37-2c3a-4435-baf2-60df52280651","type":"GlyphRenderer"},{"attributes":{"api_key":"AIzaSyCT2G-lKKPOLe6s7rypBp95apdWAUtmulo","map_options":{"lat":30.29,"lng":-97.73,"map_type":"roadmap","zoom":11},"renderers":[{"id":"96755e37-2c3a-4435-baf2-60df52280651","type":"GlyphRenderer"},{"id":"1ec0bb02-d478-4a39-9da3-8fae637eb861","type":"BoxAnnotation"}],"title":{"id":"c21e53df-fea8-41bd-b791-8279d7c9589d","type":"Title"},"tool_events":{"id":"5684ced4-009d-48e4-a6aa-eb1f8b3dc275","type":"ToolEvents"},"toolbar":{"id":"23e78005-cf61-46c9-a620-3baf77742561","type":"Toolbar"},"x_range":{"id":"635777fd-28af-4f18-bfd9-d5c153453c0e","type":"DataRange1d"},"y_range":{"id":"d079146b-a16a-4725-9985-934179ee4bf5","type":"DataRange1d"}},"id":"86bbfdd7-a20c-4084-b065-a7d593bd0fce","type":"GMapPlot"},{"attributes":{"plot":null,"text":"Austin"},"id":"c21e53df-fea8-41bd-b791-8279d7c9589d","type":"Title"},{"attributes":{"plot":{"id":"86bbfdd7-a20c-4084-b065-a7d593bd0fce","type":"GMapPlot"}},"id":"987db8ba-90a3-4cbd-9d0a-25e6f50f9b17","type":"WheelZoomTool"}],"root_ids":["86bbfdd7-a20c-4084-b065-a7d593bd0fce"]},"title":"Bokeh Application","version":"0.12.3"}};
#             var render_items = [{"docid":"320eaeed-a453-4f00-81e6-9639be079cad","elementid":"760891ea-807c-4fb3-832d-d5d2e7f89ed7","modelid":"86bbfdd7-a20c-4084-b065-a7d593bd0fce","notebook_comms_target":"6b8cab40-ad88-4068-b30c-fd0f6d35caba"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === "1")) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === "1") {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (!force) {
#         var cell = $("#760891ea-807c-4fb3-832d-d5d2e7f89ed7").parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if
# ERROR:/usr/local/lib/python2.7/site-packages/bokeh/core/validation/check.pyc:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: x, y [renderer: GlyphRenderer(id='3707ee86-113d-45ac-9734-adfb4ac6c11b', ...)]
# ERROR:/usr/local/lib/python2.7/site-packages/bokeh/core/validation/check.pyc:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: x, y [renderer: GlyphRenderer(id='8a379c79-0ba5-4036-92c6-c3575982aa64', ...)]
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>
